# %%
import preprocessing as pp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from k_means_constrained import KMeansConstrained

# %%
customer_df, candidate_df, supplier_df, vehicle_df, distance_w_to_s_df, distance_w_to_c_df, demand_cus_period_df, demand_cus_period_scene_df = pp.read_and_prep_data()

# %%
fig = plt.figure(figsize=(12,8))
plt.scatter(candidate_df['CandidateEasting'], candidate_df['CandidateNorthing'])
plt.scatter(customer_df['CustomerEasting'], customer_df['CustomerNorthing'], color = 'red')
plt.show()

# %%
asdfasdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 asdfasdf
#
# NameError: name 'asdfasdf' is not defined

# %%
# 2 methods for clustering

customer_df, cluster_center_df = pp.ori_cluster_by_cus_loc(customer_df, n_clusters=100, random_state=42, n_init=10)
# customer_df, cluster_center_df = pp.const_cluster_by_cus_loc(customer_df, n_clusters=100, size_min=4, size_max=400, random_state=42)

# %%
agg_dem_cus_period_df = pp.agg_dem_cus_period(demand_cus_period_df,customer_df)
agg_dem_cus_period_scene_df = pp.agg_dem_cus_period_scene(demand_cus_period_scene_df,customer_df)

# %%
agg_dem_cus_period_scene_df
# Out:
#                                         0        1        2         3   \
# Cluster ProductIndex PeriodIndex
# 0       1            1               339.0    296.0    341.0     344.0
#                      2               759.0    633.0    590.0     695.0
#                      3              1076.0    898.0    719.0     972.0
#                      4              1421.0   1072.0    941.0    1292.0
#                      5              2000.0   1297.0    999.0    1775.0
# ...                                    ...      ...      ...       ...
# 99      4            6             64325.0  45340.0  35642.0   55434.0
#                      7             75153.0  49583.0  43575.0   71364.0
#                      8             85244.0  50128.0  46381.0   76398.0
#                      9            107359.0  62348.0  53121.0  100674.0
#                      10           124154.0  68156.0  62107.0  109548.0
#
#                                        4         5        6        7   \
# ...

# %%
agg_dem_cus_period_df
# Out:
#                             0        1        2         3         4         5  \
# Cluster ProductIndex
# 0       1               306.0    636.0    881.0    1115.0    1396.0    1794.0
#         2                86.0    181.0    288.0     390.0     512.0     655.0
#         3              1629.0   2912.0   4310.0    5838.0    7329.0    9578.0
#         4               102.0    186.0    297.0     372.0     489.0     584.0
# 1       1               914.0   1889.0   2247.0    3355.0    3680.0    5329.0
# ...                       ...      ...      ...       ...       ...       ...
# 98      4              8242.0  14774.0  19826.0   29405.0   37847.0   42040.0
# 99      1              7181.0  16022.0  22993.0   29214.0   38109.0   47021.0
#         2              6266.0  12647.0  19348.0   24111.0   31909.0   38150.0
#         3             33689.0  65734.0  97468.0  137696.0  165996.0  207325.0
#         4              8101.0  16464.0  22432.0   31636.0   36900.0   42282.0
#
# ...

# %%
plt.figure(figsize=(10, 6))
plt.scatter(customer_df["CustomerEasting"], customer_df["CustomerNorthing"], c=customer_df["Cluster"], cmap="viridis", s=50, alpha=0.7)
plt.scatter(cluster_center_df['CustomerEasting'], cluster_center_df['CustomerNorthing'], c='red', marker='x', s=200, label='Centroids')
plt.xlabel("Customer Easting")
plt.ylabel("Customer Northing")
plt.title("K-Means Clustering (k=100)")
plt.legend()
plt.show()
